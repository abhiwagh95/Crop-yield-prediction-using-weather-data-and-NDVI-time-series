# 22           0.63  0.40
# 23           0.59  0.34
# 24           0.66  0.31
# 25           0.69  0.32
# 26           0.68  0.29
# 27           0.66  0.33
# 28           0.62  0.34
# 29           0.44  0.39
# 30           0.33  0.40
# 31           0.38  0.43
# 32           0.44  0.45
# 33           0.53  0.45
# 34           0.63  0.41
# 35           0.59  0.38
# 36           0.66  0.34
# 37           0.69  0.35
# 38           0.68  0.30
# 39           0.66  0.29
# 40           0.62  0.34
# 41           0.44  0.38
# 42           0.33  0.40
# 43           0.38  0.40
# 44           0.44  0.40
# 45           0.53  0.40
# 46           0.63  0.41
# 47           0.59  0.36

# %%
ndvi_data.describe()
# Out:
#               Year      Month  Precipitation    maxtemp    mintemp    avgtemp  \
# count    48.000000  48.000000      48.000000  48.000000  48.000000  48.000000
# mean   2017.500000   6.500000      56.360208  32.853542  19.328750  13.524375
# std       1.129865   3.488583      80.259356   4.027031   3.733373   4.020054
# min    2016.000000   1.000000       0.000000  28.420000  12.820000   7.030000
# 25%    2016.750000   3.750000       0.987500  29.775000  16.260000   9.237500
# 50%    2017.500000   6.500000       4.850000  31.010000  20.605000  14.960000
# 75%    2018.250000   9.250000     125.405000  35.595000  22.042500  17.012500
# max    2019.000000  12.000000     267.600000  40.700000  24.470000  19.050000
#
#        specifichumidity  relativehumidity  surfacepressure  dewpoints  \
# count         48.000000         48.000000        48.000000  48.000000
# mean           0.011349         52.564167        94.089583  13.548125
# std            0.004334         21.100176         0.281500   6.521749
# min            0.005095         24.090000        93.640000   2.700000
# 25%            0.007136         31.342500        93.817500   7.140000
# 50%            0.011342         53.950000        94.075000  14.730000
# 75%            0.016198         74.360000        94.382500  20.520000
# max            0.017074         80.840000        94.510000  21.400000
#
#        minwindspeed  maxwindspeed  cloudcoverage       NDVI
# count     48.000000     48.000000      48.000000  48.000000
# mean       2.352083      5.841667       0.549167   0.366042
# std        1.238900      1.974804       0.126135   0.052257
# min        1.030000      3.560000       0.270000   0.240000
# 25%        1.527500      4.362500       0.440000   0.330000
# 50%        1.800000      4.880000       0.620000   0.375000
# 75%        3.347500      7.145000       0.660000   0.400000
# max        5.230000     10.570000       0.690000   0.460000

# %%
ndvi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
# Year                48 non-null int64
# Month               48 non-null int64
# Precipitation       48 non-null float64
# maxtemp             48 non-null float64
# mintemp             48 non-null float64
# avgtemp             48 non-null float64
# specifichumidity    48 non-null float64
# relativehumidity    48 non-null float64
# surfacepressure     48 non-null float64
# dewpoints           48 non-null float64
# minwindspeed        48 non-null float64
# maxwindspeed        48 non-null float64
# cloudcoverage       48 non-null float64
# NDVI                48 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 5.4 KB

# %%
ndvi_data['Year'] = ndvi_data['Year'].astype(np.float64)
ndvi_data['Month'] = ndvi_data['Month'].astype(np.float64)

# %%
ndvi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 14 columns):
# Year                48 non-null float64
# Month               48 non-null float64
# Precipitation       48 non-null float64
# maxtemp             48 non-null float64
# mintemp             48 non-null float64
# avgtemp             48 non-null float64
# specifichumidity    48 non-null float64
# relativehumidity    48 non-null float64
# surfacepressure     48 non-null float64
# dewpoints           48 non-null float64
# minwindspeed        48 non-null float64
# maxwindspeed        48 non-null float64
# cloudcoverage       48 non-null float64
# NDVI                48 non-null float64
# dtypes: float64(14)
# memory usage: 5.4 KB

# %%
#Creating the correlation matrix for the features
corr_matrix=ndvi_data.corr()
corr_matrix
# Out:
#                       Year     Month  Precipitation   maxtemp   mintemp  \
# Year              1.000000  0.000000      -0.004989 -0.000351  0.001866
# Month             0.000000  1.000000       0.148085 -0.561810 -0.122195
# Precipitation    -0.004989  0.148085       1.000000 -0.303040  0.349011
# maxtemp          -0.000351 -0.561810      -0.303040  1.000000  0.465366
# mintemp           0.001866 -0.122195       0.349011  0.465366  1.000000
# avgtemp          -0.002131 -0.449319      -0.627631  0.569608 -0.462416
# specifichumidity -0.002212  0.467125       0.605351 -0.399400  0.603648
# relativehumidity -0.010727  0.635262       0.571855 -0.725572  0.238051
# surfacepressure  -0.024751 -0.053514      -0.487878 -0.081643 -0.873844
# dewpoints        -0.008446  0.513159       0.552467 -0.383650  0.599470
# minwindspeed     -0.043320  0.168706       0.430825 -0.284067  0.487038
# maxwindspeed     -0.013159  0.035146       0.361780 -0.106342  0.584893
# cloudcoverage     0.053746 -0.376666      -0.630956  0.517679 -0.466539
# NDVI              0.131529  0.598138       0.259012 -0.594600 -0.022786
#
#                    avgtemp  specifichumidity  relativehumidity  \
# Year             -0.002131         -0.002212         -0.010727
# Month            -0.449319          0.467125          0.635262
# Precipitation    -0.627631          0.605351          0.571855
# maxtemp           0.569608         -0.399400         -0.725572
# mintemp          -0.462416          0.603648          0.238051
# avgtemp           1.000000         -0.960679         -0.947949
# specifichumidity -0.960679          1.000000          0.913410
# relativehumidity -0.947949          0.913410          1.000000
# surfacepressure   0.729716         -0.820773         -0.566558
# dewpoints        -0.941050          0.993834          0.907546
# minwindspeed     -0.736796          0.728494          0.643930
# maxwindspeed     -0.649620          0.652711          0.509130
# cloudcoverage     0.951754         -0.908784         -0.884695
# NDVI             -0.574448          0.538309          0.676118
#
#                   surfacepressure  dewpoints  minwindspeed  maxwindspeed  \
# Year                    -0.024751  -0.008446     -0.043320     -0.013159
# Month                   -0.053514   0.513159      0.168706      0.035146
# Precipitation           -0.487878   0.552467      0.430825      0.361780
# maxtemp                 -0.081643  -0.383650     -0.284067     -0.106342
# mintemp                 -0.873844   0.599470      0.487038      0.584893
# avgtemp                  0.729716  -0.941050     -0.736796     -0.649620
# specifichumidity        -0.820773   0.993834      0.728494      0.652711
# relativehumidity        -0.566558   0.907546      0.643930      0.509130
# surfacepressure          1.000000  -0.803908     -0.769578     -0.802401
# dewpoints               -0.803908   1.000000      0.699637      0.623340
# minwindspeed            -0.769578   0.699637      1.000000      0.963089
# maxwindspeed            -0.802401   0.623340      0.963089      1.000000
# cloudcoverage            0.749919  -0.878132     -0.821232     -0.772701
# NDVI                    -0.182501   0.543093      0.273394      0.184240
#
#                   cloudcoverage      NDVI
# Year                   0.053746  0.131529
# Month                 -0.376666  0.598138
# Precipitation         -0.630956  0.259012
# maxtemp                0.517679 -0.594600
# mintemp               -0.466539 -0.022786
# avgtemp                0.951754 -0.574448
# specifichumidity      -0.908784  0.538309
# relativehumidity      -0.884695  0.676118
# surfacepressure        0.749919 -0.182501
# dewpoints             -0.878132  0.543093
# minwindspeed          -0.821232  0.273394
# maxwindspeed          -0.772701  0.184240
# cloudcoverage          1.000000 -0.510522
# NDVI                  -0.510522  1.000000

# %%
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(10, 8)) 
heatmap = sns.heatmap(corr_matrix, mask = mask,square = True,linewidths = .5, cmap = 'coolwarm', cbar_kws = {'shrink': .4, 'ticks' : [-1, -.5, 0, 0.5, 1]},vmin = -1, vmax = 1,annot = True,annot_kws = {'size': 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
ndvi_data=ndvi_data.drop(['maxtemp','avgtemp','surfacepressure','maxwindspeed','cloudcoverage'],axis=1)

# %%
ndvi_data1=ndvi_data.iloc[:,:].values

# %%
ndvi_data1
# Out:
# array([[2.0160e+03, 1.0000e+00, 0.0000e+00, 1.4270e+01, 5.4120e-03,
#         3.0360e+01, 3.5100e+00, 1.3300e+00, 3.1000e-01],
#        [2.0160e+03, 2.0000e+00, 5.2200e+00, 1.7800e+01, 7.1300e-03,
#         3.1670e+01, 7.3600e+00, 1.0300e+00, 3.5000e-01],
#        [2.0160e+03, 3.0000e+00, 7.3300e+00, 2.1260e+01, 7.7530e-03,
#         2.9020e+01, 8.5700e+00, 1.2600e+00, 3.1000e-01],
#        [2.0160e+03, 4.0000e+00, 4.4400e+00, 2.3560e+01, 8.8200e-03,
#         2.7680e+01, 1.0630e+01, 1.5700e+00, 2.5000e-01],
#        [2.0160e+03, 5.0000e+00, 7.5900e+00, 2.4470e+01, 1.2476e-02,
#         3.9870e+01, 1.5920e+01, 3.3300e+00, 2.4000e-01],
#        [2.0160e+03, 6.0000e+00, 1.0436e+02, 2.3130e+01, 1.6247e-02,
#         6.8080e+01, 2.0530e+01, 3.7700e+00, 2.9000e-01],
#        [2.0160e+03, 7.0000e+00, 2.6760e+02, 2.2000e+01, 1.6977e-02,
#         8.0840e+01, 2.1290e+01, 4.1700e+00, 3.3000e-01],
#        [2.0160e+03, 8.0000e+00, 1.8400e+02, 2.1240e+01, 1.6542e-02,
#         8.0130e+01, 2.0880e+01, 4.1200e+00, 3.9000e-01],
#        [2.0160e+03, 9.0000e+00, 1.7128e+02, 2.0630e+01, 1.5898e-02,
#         8.0120e+01, 2.0230e+01, 2.9800e+00, 4.2000e-01],
#        [2.0160e+03, 1.0000e+01, 4.7530e+01, 1.7600e+01, 1.3234e-02,
#         7.0490e+01, 1.7110e+01, 1.9000e+00, 4.5000e-01],
#        [2.0160e+03, 1.1000e+01, 2.1500e+00, 1.2980e+01, 8.6340e-03,
#        [2.0190e+03, 1.1000e+01, 1.7290e+01, 1.4770e+01, 1.0980e-02,
#         6.4330e+01, 1.4280e+01, 1.6900e+00, 4.1000e-01],
#        [2.0190e+03, 1.2000e+01, 2.6800e+00, 1.3460e+01, 9.1190e-03,
#         5.6530e+01, 1.1060e+01, 1.8000e+00, 3.6000e-01]])

# %%
X=ndvi_data1[:,:-1]
y=ndvi_data1[:,-1]

# %%
X.shape
# Out:
# (48, 8)

# %%
y.shape
# Out:
# (48,)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=101)

# %%
X_train,y_train=np.array(X_train),np.array(y_train)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %% [markdown]
# ### Linear Regressor

# %%
li=LinearRegression()
li.fit(X_train,y_train)
Lir_ypred= li.predict(X_test)
Lir_ypred
# Out:
# array([0.3430969 , 0.40033841, 0.41765557, 0.34015399, 0.36849831])

# %%
Linear=pd.DataFrame({'Actual':y_test,'Predicted':Lir_ypred})
Linear
# Out:
#    Actual  Predicted
# 0    0.34   0.343097
# 1    0.40   0.400338
# 2    0.41   0.417656
# 3    0.30   0.340154
# 4    0.42   0.368498

# %%
from sklearn.metrics import mean_squared_error,r2_score
#print('Mean Absolute Error:',mean_absolute_error(y_test,Lir_ypred))
print('Mean squared Error:',mean_squared_error(y_test,Lir_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lir_ypred)))
#print('R2_Score:',r2_score(y_test,Lir_ypred))
# Out:
# Mean squared Error: 0.0008666160734414595
# Root Mean Squared Error: 0.02943834359201379

# %%
linear_r2_score=r2_score(y_test,Lir_ypred)
linear_r2_score
# Out:
# 0.5957947418649909

# %% [markdown]
# ### Lasso Regressor

# %%
#Lasso Regressor
lass=Lasso(alpha=0.0001)
lass.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
Lass_ypred= lass.predict(X_test)
print('Mean squared Error:',mean_squared_error(y_test,Lass_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,Lass_ypred)))
#print('R2_Score:',r2_score(y_test,Lass_ypred))
# Out:
# Mean squared Error: 0.0007770485335193741
# Root Mean Squared Error: 0.027875590281093137

# %%
lasso_r2_score=r2_score(y_test,Lass_ypred)
lasso_r2_score
# Out:
# 0.6375706466793964

# %% [markdown]
# ### Ridge Regressor

# %%
#RIdge
rid=Ridge(alpha=0.0001)
rid.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
rid_ypred= rid.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,rid_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rid_ypred)))
#print('R2_Score:',r2_score(y_test,rid_ypred))
# Out:
# Mean squared Error: 0.0007919736649716694
# Root Mean Squared Error: 0.028142026667808937

# %%
ridge_r2_score=r2_score(y_test,rid_ypred)
ridge_r2_score
# Out:
# 0.6306092980542586

# %% [markdown]
# ### Decision Tree Regressor

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt_ypred= dt.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,dt_ypred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,dt_ypred)))
#print('R2_Score:',r2_score(y_test,dt_ypred))
# Out:
# Mean squared Error: 0.0007999999999999997
# Root Mean Squared Error: 0.028284271247461894

# %%
decisiontree_r2_score=r2_score(y_test,dt_ypred)
decisiontree_r2_score
# Out:
# 0.6268656716417911

# %% [markdown]
# ### KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

kn=KNeighborsRegressor(n_neighbors=4)
kn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                     weights='uniform')

# %%
kn1_pred=kn.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,kn1_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,kn1_pred)))
#print('R2_Score:',r2_score(y_test,kn1_pred))
# Out:
# Mean squared Error: 0.00020500000000000019
# Root Mean Squared Error: 0.01431782106327636

# %%
kneighbour_r2_score=r2_score(y_test,kn1_pred)
kneighbour_r2_score
# Out:
# 0.9043843283582088

# %% [markdown]
# ### SVR Regressor

# %%
from sklearn.svm import SVR
svr=SVR(kernel='rbf')
svr.fit(X_train,y_train)
svr_pred=svr.predict(X_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print('Mean squared Error:',mean_squared_error(y_test,svr_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,svr_pred)))
#print('R2_Score:',r2_score(y_test,svr_pred))
# Out:
# Mean squared Error: 0.0026782503994437594
# Root Mean Squared Error: 0.05175181542171984

# %%
svr_r2_score=r2_score(y_test,svr_pred)
svr_r2_score
# Out:
# -0.24918395496444012

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 10000, random_state = 45)
rf.fit(X_train, y_train)
rf_pred=rf.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,rf_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,rf_pred)))
#print('R2_Score:',r2_score(y_test,rf_pred))
# Out:
# Mean squared Error: 0.0004353541993995714
# Root Mean Squared Error: 0.020865143167483214

# %%
randomforest_r2_score=r2_score(y_test,rf_pred)
randomforest_r2_score
# Out:
# 0.796943004011394

# %% [markdown]
# ### Bayes Regressor

# %%
from sklearn.linear_model import BayesianRidge
br=BayesianRidge()
br.fit(X_train,y_train)
y_pred=br.predict(X_test)

# %%
bay=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
bay
# Out:
#    Actual  Predicted
# 0    0.34   0.342304
# 1    0.40   0.401286
# 2    0.41   0.397492
# 3    0.30   0.321331
# 4    0.42   0.391517

# %%
print('Mean squared Error:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred)))
#print('R2_Score:',r2_score(y_test,y_pred))
# Out:
# Mean squared Error: 0.0002859366724508552
# Root Mean Squared Error: 0.016909662103390923

# %%
bayes_r2_score=r2_score(y_test,y_pred)
bayes_r2_score
# Out:
# 0.8666340147150862

# %% [markdown]
# ### Elastic Net Regressor

# %%
from sklearn.linear_model import ElasticNet

# %%
el=ElasticNet()

# %%
el.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
y_pred=el.predict(X_test)

# %%
print('Mean squared Error:',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred)))
#print('R2_Score:',r2_score(y_test,y_pred))
# Out:
# Mean squared Error: 0.0013911545042766729
# Root Mean Squared Error: 0.037298183659216874

# %%
elasticnet_r2_score=r2_score(y_test,y_pred)
elasticnet_r2_score
# Out:
# 0.35114062300528315

# %%
Regressors=['Linear','Lasso','Ridge','DecisionTree','KNeighbour','RandomForest','Bayesian','ElasticNet']
R2_Score=[linear_r2_score,lasso_r2_score,ridge_r2_score,decisiontree_r2_score,kneighbour_r2_score,randomforest_r2_score,bayes_r2_score,elasticnet_r2_score]

# %%
plt.figure(figsize=(15,4))
plt.plot(Regressors,R2_Score, color = 'Red')

plt.title('Comparision between different Regressors',fontsize=15)
plt.xlabel('Regressors',fontsize=15)
plt.ylabel('Accuracy Values',fontsize=15)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # KNeighbour Regressor is sutaible for NDVI with accuracy of 90% followed by Bayesian Regressor with accuracy of 86.66%

# %%
Phase1_Output=pd.read_csv("C:/Users/Abhishek Wagh/Desktop/MTech_Project/Sugarcane/Phase2/csv/Phase1_Output.csv")
Phase1_Output
# Out:
#     Year  Month  precipitation    maxtemp  mintemp    avgtemp  \
# 0   2020      1           0.00  30.325833   14.014  17.590714
# 1   2020      2         158.06  34.087500   15.819  17.070000
# 2   2020      3          14.16  37.637500   20.420  17.120000
# 3   2020      4          35.89  39.143333   21.943  17.357857
# 4   2020      5           8.06  39.327500   23.074  15.757857
# 5   2020      6         158.06  31.120833   22.771   8.800714
# 6   2020      7         104.36  30.160833   21.943   7.902857
# 7   2020      8           4.31  30.368333   21.173   8.602143
# 8   2020      9         158.06  30.299167   20.742   9.897143
# 9   2020     10         104.36  30.950833   20.420  11.557857
# 10  2020     11           0.01  30.089167   14.973  15.060000
# 11  2020     12           0.01  29.567500   14.358  15.584286
#
#     specifichumidity  relativehumidity  surfacepressure  dewpoints  \
# 0           0.005498          36.74041        94.393481   5.237143
# 1           0.005498          28.18608        94.397122   5.237143
# 2           0.006759          24.98620        94.165634   6.314286
# 3           0.006759          25.64483        94.020611   6.397143
# 4           0.009510          39.15415        93.875285  14.858571
# 5           0.016585          74.29077        93.720251  20.814286
# 6           0.016585          76.24217        93.720857  20.891429
# 7           0.016404          75.63663        93.784572  20.645714
# 8           0.016636          71.70818        94.008781  20.597143
# 9           0.016054          54.11695        94.172312  19.138571
# 10          0.010050          51.37936        94.343121  12.240000
# 11          0.010050          48.47239        94.433531   9.334286
#
#     minwindspeed  maxwindspeed  cloudcoverage
# 0       1.434167         4.510       0.660000
# 1       1.325000         4.575       0.678000
# 2       1.290833         4.863       0.676000
# 3       1.380000         5.264       0.660000
# 4       2.745000         6.944       0.639333
# 5       3.960833         8.045       0.440667
# 6       5.100000         9.281       0.348000
# 7       4.464167         8.853       0.378667
# 8       2.286667         5.193       0.440667
# 9       1.735000         4.454       0.534000
# 10      1.955000         4.814       0.638000
# 11      1.795000         4.647       0.598667

# %%
Phase1_Output=Phase1_Output.drop(['maxtemp','avgtemp','surfacepressure','maxwindspeed','cloudcoverage'],axis=1)

# %%
Phase1_Output=Phase1_Output.iloc[:,:].values

# %%
Phase1_Output
# Out:
# array([[2.02000000e+03, 1.00000000e+00, 0.00000000e+00, 1.40140000e+01,
#         5.49800000e-03, 3.67404100e+01, 5.23714286e+00, 1.43416667e+00],
#        [2.02000000e+03, 2.00000000e+00, 1.58060000e+02, 1.58190000e+01,
#         5.49800000e-03, 2.81860800e+01, 5.23714286e+00, 1.32500000e+00],
#        [2.02000000e+03, 3.00000000e+00, 1.41600000e+01, 2.04200000e+01,
#         6.75900000e-03, 2.49862000e+01, 6.31428571e+00, 1.29083333e+00],
#        [2.02000000e+03, 4.00000000e+00, 3.58900000e+01, 2.19430000e+01,
#         6.75900000e-03, 2.56448300e+01, 6.39714286e+00, 1.38000000e+00],
#        [2.02000000e+03, 5.00000000e+00, 8.06000000e+00, 2.30740000e+01,
#         9.51050000e-03, 3.91541500e+01, 1.48585714e+01, 2.74500000e+00],
#        [2.02000000e+03, 6.00000000e+00, 1.58060000e+02, 2.27710000e+01,
#         1.65850000e-02, 7.42907700e+01, 2.08142857e+01, 3.96083333e+00],
#        [2.02000000e+03, 7.00000000e+00, 1.04360000e+02, 2.19430000e+01,
#         1.65850000e-02, 7.62421700e+01, 2.08914286e+01, 5.10000000e+00],
#        [2.02000000e+03, 8.00000000e+00, 4.31000000e+00, 2.11730000e+01,
#         1.64040000e-02, 7.56366300e+01, 2.06457143e+01, 4.46416667e+00],
#        [2.02000000e+03, 9.00000000e+00, 1.58060000e+02, 2.07420000e+01,
#         1.66360000e-02, 7.17081800e+01, 2.05971429e+01, 2.28666667e+00],
#        [2.02000000e+03, 1.00000000e+01, 1.04360000e+02, 2.04200000e+01,
#         1.60540000e-02, 5.41169500e+01, 1.91385714e+01, 1.73500000e+00],
#        [2.02000000e+03, 1.10000000e+01, 1.00000000e-02, 1.49730000e+01,
#         1.00495000e-02, 5.13793600e+01, 1.22400000e+01, 1.95500000e+00],
#        [2.02000000e+03, 1.20000000e+01, 1.00000000e-02, 1.43580000e+01,
#         1.00495000e-02, 4.84723900e+01, 9.33428571e+00, 1.79500000e+00]])

# %%
Phase1_Output_predict=[]

# %%
#Using Kneighbour regressor for prediction
Phase1_Output_predict=kn.predict(Phase1_Output)

# %%
Phase1_Output_predict
# Out:
# array([0.3225, 0.4025, 0.3225, 0.32  , 0.3075, 0.42  , 0.3725, 0.4175,
#        0.42  , 0.3725, 0.405 , 0.38  ])

# %%
#Predicting for 2020
ndvi_data=pd.DataFrame(data=Phase1_Output_predict)
ndvi_data
# Out:
#          0
# 0   0.3225
# 1   0.4025
# 2   0.3225
# 3   0.3200
# 4   0.3075
# 5   0.4200
# 6   0.3725
# 7   0.4175
# 8   0.4200
# 9   0.3725
# 10  0.4050
# 11  0.3800

# %%
#Exporting the predictions of 2020 into csv file
ndvi_data.to_csv(r"C:\Users\Abhishek Wagh\Desktop\MTech_Project\Sugarcane\Phase2\csv\2020ndvi.csv")

# %%
month=['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
plt.figure(figsize=(15,4))
plt.plot(month,ndvi_data, color = 'Red')

plt.title('2020 NDVI Data',fontsize=15)
plt.xlabel('Months',fontsize=15)
plt.ylabel('NDVI Values',fontsize=15)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
